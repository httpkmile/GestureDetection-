# %% [markdown]
# # Coletor de Dados: Hand Landmarks para CSV
#
# Este notebook permite capturar as coordenadas dos marcos das mãos (hand landmarks) usando a webcam e salvá-los em um arquivo CSV. Esses dados podem ser usados posteriormente para treinar um modelo de classificação de gestos.
#
# ### Instruções:
# 1. Defina a `TARGET_LABEL` (etiqueta) para o gesto que você vai fazer.
# 2. Execute o loop da webcam.
# 3. Pressione **'s'** para salvar os marcos atuais da mão no CSV.
# 4. Pressione **'q'** para sair.

# %%
import cv2 as cv
import mediapipe as mp
import numpy as np
import time
import os
import joblib as jb

print("Bibliotecas carregadas!")
# Out:
# Bibliotecas carregadas!

# %% [markdown]
# ### Configurações de Coleta
# Altere o `TARGET_LABEL` conforme o gesto que estiver gravando.

# %%
TARGET_LABEL = "maoaberta"
CSV_FILE = "../data/hand_landmarks_data.csv"
MODEL_PATH = "../models/hand_landmarker.task"

print(f"Coletando dados para a label: {TARGET_LABEL}")
print(f"Arquivo de destino: {CSV_FILE}")
# Out:
# Coletando dados para a label: maoaberta
# Arquivo de destino: ../data/hand_landmarks_data.csv

# %% [markdown]
# ### Funções Auxiliares

# %%
def draw_hand_landmarks(frame, hand_landmarks):
    """Desenha os pontos e conexões da mão manualmente usando OpenCV."""
    HAND_CONNECTIONS = [
        (0, 1), (1, 2), (2, 3), (3, 4),
        (0, 5), (5, 6), (6, 7), (7, 8),
        (5, 9), (9, 10), (10, 11), (11, 12),
        (9, 13), (13, 14), (14, 15), (15, 16),
        (13, 17), (17, 18), (18, 19), (19, 20), (0, 17)
    ]

    h, w, _ = frame.shape
    for connection in HAND_CONNECTIONS:
        start_idx, end_idx = connection
        start_point = (int(hand_landmarks[start_idx].x * w), int(hand_landmarks[start_idx].y * h))
        end_point = (int(hand_landmarks[end_idx].x * w), int(hand_landmarks[end_idx].y * h))
        cv2.line(frame, start_point, end_point, (255, 255, 255), 2)

    for landmark in hand_landmarks:
        cx, cy = int(landmark.x * w), int(landmark.y * h)
        cv2.circle(frame, (cx, cy), 5, (0, 0, 255), -1)

def save_landmarks_to_csv(landmarks, label, filename):
    """Salva os marcos no arquivo CSV."""
    file_exists = os.path.isfile(filename)
    with open(filename, mode='a', newline='') as f:
        writer = csv.writer(f)
        if not file_exists:

            header = ['label']
            for i in range(21):
                header.extend([f'x{i}', f'y{i}', f'z{i}'])
            writer.writerow(header)

        row = [label]
        for lm in landmarks:
            row.extend([lm.x, lm.y, lm.z])
        writer.writerow(row)

# %% [markdown]
# ### Loop de Captura e Gravação
#
# - **'s'**: Salva os dados atuais de TODAS as mãos detectadas no CSV.
# - **'q'**: Sai do loop.

# %%
BaseOptions = mp.tasks.BaseOptions
HandLandmarker = mp.tasks.vision.HandLandmarker
HandLandmarkerOptions = mp.tasks.vision.HandLandmarkerOptions
VisionRunningMode = mp.tasks.vision.RunningMode

options = HandLandmarkerOptions(
    base_options=BaseOptions(model_asset_path=MODEL_PATH),
    running_mode=VisionRunningMode.VIDEO,
    num_hands=1
)

cap = cv2.VideoCapture(0)
last_timestamp_ms = 0
count_saved = 0

print("Iniciando webcam... Pressione 's' para salvar e 'q' para sair.")

try:
    with HandLandmarker.create_from_options(options) as landmarker:
        while cap.isOpened():
            success, frame = cap.read()
            if not success:
                print("Ignorando frame vazio da câmera.")
                continue

            frame = cv2.flip(frame, 1)
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)

            timestamp_ms = int(time.time() * 1000)
            if timestamp_ms <= last_timestamp_ms:
                timestamp_ms = last_timestamp_ms + 1
            last_timestamp_ms = timestamp_ms

            all_current_landmarks = []
            try:
                result = landmarker.detect_for_video(mp_image, timestamp_ms)
                if result.hand_landmarks:
                    all_current_landmarks = result.hand_landmarks
                    for hand_landmarks in all_current_landmarks:
                        draw_hand_landmarks(frame, hand_landmarks)

                    cv2.putText(frame, f"{len(all_current_landmarks)} Mao(s) - Label: {TARGET_LABEL}", (10, 30),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
                else:
                    cv2.putText(frame, "Mao nao detectada", (10, 30),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
            except Exception as e:
                print(f"Erro no MediaPipe: {e}")
                continue

            cv2.putText(frame, f"Total Salvos: {count_saved}", (10, 60),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

            cv2.imshow('Coletor de Hand Landmarks (Multi-Hand)', frame)

            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                break
            elif key == ord('s'):
                if all_current_landmarks:
                    for hand_lms in all_current_landmarks:
                        save_landmarks_to_csv(hand_lms, TARGET_LABEL, CSV_FILE)
                        count_saved += 1
                    print(f"Salvo {len(all_current_landmarks)} mao(s). Total acumulado: {count_saved}")
                else:
                    print("Nenhuma mao detectada no frame para salvar!")
finally:
    cap.release()
    cv2.destroyAllWindows()

    cv2.waitKey(1)
    print(f"Processo finalizado. Amostras totais nesta sessao: {count_saved}")
# Out:
# Iniciando webcam... Pressione 's' para salvar e 'q' para sair.
# Processo finalizado. Amostras totais nesta sessao: 0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 19
#      16 print("Iniciando webcam... Pressione 's' para salvar e 'q' para sair.")
#      18 try:
# ---> 19     with HandLandmarker.create_from_options(options) as landmarker:
#      20         while cap.isOpened():
#      21             success, frame = cap.read()
#
# File c:\Users\camil\configgesture\.venv\Lib\site-packages\mediapipe\tasks\python\vision\hand_landmarker.py:422, in HandLandmarker.create_from_options(cls, options)
#     411 ctypes_options = HandLandmarkerOptionsC.from_c_options(
#     412     base_options=options.base_options.to_ctypes(),
#     413     running_mode=options.running_mode,
#    (...)    418     result_callback=c_callback,
#     419 )
#     421 landmarker_handle = ctypes.c_void_p()
# --> 422 lib.MpHandLandmarkerCreate(
#     423     ctypes.byref(ctypes_options),
#     424     ctypes.byref(landmarker_handle),
#     425 )
#     426 return HandLandmarker(
#     427     lib=lib,
#     428     handle=landmarker_handle,
#     429     dispatcher=dispatcher,
#     430     async_callback=c_callback,
#     431 )
#
# File c:\Users\camil\configgesture\.venv\Lib\site-packages\mediapipe\tasks\python\core\serial_dispatcher.py:74, in SerialDispatcher._register_signature.<locals>.shutdown_aware_handler(*args, **kwargs)
#      72   if self._is_closed:
#      73     return
# ---> 74 return handler(*args, **kwargs)
#
# File c:\Users\camil\configgesture\.venv\Lib\site-packages\mediapipe\tasks\python\core\mediapipe_c_utils.py:142, in CStatusFunction.create_python_wrapper.<locals>.dispatcher_wrapper(*args, **kwargs)
#     139     if error_msg.value is not None:
#     140       lib.MpErrorFree(error_msg)
# --> 142 executor.submit(dispatch_and_free).result()
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\_base.py:450, in Future.result(self, timeout)
#     448     raise CancelledError()
#     449 elif self._state == FINISHED:
# --> 450     return self.__get_result()
#     451 else:
#     452     raise TimeoutError()
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File c:\Users\camil\configgesture\.venv\Lib\site-packages\mediapipe\tasks\python\core\mediapipe_c_utils.py:137, in CStatusFunction.create_python_wrapper.<locals>.dispatcher_wrapper.<locals>.dispatch_and_free()
#     135 status = c_func(*call_args, **kwargs)
#     136 try:
# --> 137   handle_status(status, error_msg)
#     138 finally:
#     139   if error_msg.value is not None:
#
# File c:\Users\camil\configgesture\.venv\Lib\site-packages\mediapipe\tasks\python\core\mediapipe_c_utils.py:232, in handle_status(status, error_message)
#     230 exception = convert_to_exception(status, error_message)
#     231 if exception:
# --> 232   raise exception
#
# FileNotFoundError: Unable to open file at ../models/hand_landmarker.task
